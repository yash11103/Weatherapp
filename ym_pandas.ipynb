# %% [markdown]
# <a href="https://colab.research.google.com/github/yash11103/Weatherapp/blob/main/ym_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = {
    'Name': ['yash', 'harshit', 'rens', 'adi', 'harsh', 'ayush'],
    'Marks': [55,40,45,67,77,89]
        }

# %%
data
# Out:
# {'Name': ['yash', 'harshit', 'rens', 'adi', 'harsh', 'ayush'],
#  'Marks': [55, 40, 45, 67, 77, 89]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  marks
# 0     yash     55
# 1  harshit     40
# 2     rens     45
# 3      adi     67
# 4    harsh     77
# 5    ayush     89

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   marks   6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df = pd.read_csv('/content/sample_data/cars (1) (2).csv')
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
df2 = pd.read_csv('/content/sample_data/bank-additional-full.csv')
df2
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41197   NaN        NaN      NaN                  NaN      NaN     NaN  NaN
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
# ...

# %%
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
df2.head(10)
# Out:
#     age          job  marital            education  default housing loan  \
# 0  56.0    housemaid  married             basic.4y       no      no   no
# 1  57.0     services  married          high.school  unknown      no   no
# 2  37.0     services  married          high.school       no     yes   no
# 3  40.0       admin.  married             basic.6y       no      no   no
# 4  56.0     services  married          high.school       no      no  yes
# 5  45.0     services  married             basic.9y  unknown      no   no
# 6  59.0       admin.  married  professional.course       no      no   no
# 7  41.0  blue-collar  married              unknown  unknown      no   no
# 8  24.0   technician   single  professional.course       no     yes   no
# 9  25.0     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# ...

# %%
df2.tail(10)
# Out:
#         age      job  marital            education default housing loan  \
# 41189   NaN  retired      NaN  professional.course      no     yes   no
# 41190  74.0      NaN  married                  NaN      no     yes   no
# 41191   NaN      NaN      NaN                  NaN     NaN     NaN  NaN
# 41192  74.0  retired      NaN  professional.course     NaN     yes   no
# 41193  94.0  retired  married  professional.course      no     yes   no
# 41194  74.0  retired  married  professional.course      no     yes   no
# 41195  74.0      NaN  married  professional.course      no     yes   no
# 41196  74.0  retired  married                  NaN      no     yes   no
# 41197   NaN      NaN      NaN                  NaN     NaN     NaN  NaN
# 41198  74.0  retired  married  professional.course      no     yes  NaN
#
#         contact month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 41189  cellular   nov         fri  ...       3.0  999.0       1.0       NaN
# ...

# %%
a = df2.shape
print(f'there are {a[0]} rows and {a[1]} columns')
# Out:
# there are 41199 rows and 21 columns

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
# ...

# %%
df2.describe().T
# Out:
#                   count         mean         std       min       25%  \
# age             41195.0    40.030319   10.431818    17.000    32.000
# duration        41196.0   258.281265  259.254211     0.000   102.000
# campaign        41196.0     2.567676    2.769751     1.000     1.000
# pdays           41196.0   962.482547  186.893451     0.000   999.000
# previous        41196.0     0.173124    0.494987     0.000     0.000
# emp.var.rate    41196.0     0.081656    1.570894    -3.400    -1.800
# cons.price.idx  41195.0    93.575867    0.578999    92.201    93.075
# cons.conf.idx   41196.0   -40.504600    4.629972   -50.800   -42.700
# euribor3m       41196.0     3.620787    1.734655     0.634     1.344
# nr.employed     41196.0  5166.996405   72.300104  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# ...

# %%
df2.describe(include = 'O').T
# Out:
#              count unique                top   freq
# job          41194     12             admin.  10422
# marital      41194      4            married  24934
# education    41194      8  university.degree  12168
# default      41195      3                 no  32595
# housing      41196      3                yes  21584
# loan         41195      3                 no  33957
# contact      41195      2           cellular  26151
# month        41196     10                may  13769
# day_of_week  41196      5                thu   8623
# poutcome     41194      3        nonexistent  35563
# y            41196      2                 no  36556

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  marks
# 0     yash     55
# 1  harshit     40
# 2     rens     45
# 3      adi     67
# 4    harsh     77
# 5    ayush     89

# %%
df[['Name','marks']]
# Out:
#       Name  marks
# 0     yash     55
# 1  harshit     40
# 2     rens     45
# 3      adi     67
# 4    harsh     77
# 5    ayush     89

# %% [markdown]
# loc and iloc

# %%
df
# Out:
#       Name  marks
# 0     yash     55
# 1  harshit     40
# 2     rens     45
# 3      adi     67
# 4    harsh     77
# 5    ayush     89

# %%
df.iloc[3]
# Out:
# Name     adi
# marks     67
# Name: 3, dtype: object

# %%
df.iloc[[3],[0]]
# Out:
#   Name
# 3  adi

# %%
df.iloc[[0,1,3],[0]]
# Out:
#       Name
# 0     yash
# 1  harshit
# 3      adi

# %% [markdown]
# filtering conditional

# %%
df
# Out:
#       Name  marks
# 0     yash     55
# 1  harshit     40
# 2     rens     45
# 3      adi     67
# 4    harsh     77
# 5    ayush     89

# %%
df[df['marks']>70]
# Out:
#     Name  marks
# 4  harsh     77
# 5  ayush     89

# %%
#multiple conditions
df[(df['marks']>70) & (df['marks']<90)]
# Out:
#     Name  marks
# 4  harsh     77
# 5  ayush     89

# %% [markdown]
# modifications of dfs

# %%
df
# Out:
#       Name  marks
# 0     yash     55
# 1  harshit     40
# 2     rens     45
# 3      adi     67
# 4    harsh     77
# 5    ayush     89

# %%
df['marks'] = df['marks']+5
df
# Out:
#       Name  marks
# 0     yash     70
# 1  harshit     55
# 2     rens     60
# 3      adi     82
# 4    harsh     92
# 5    ayush    104

# %%
df['country'] = ['india','usa','india','india','india','india']
df
# Out:
#       Name  marks country
# 0     yash     70   india
# 1  harshit     55     usa
# 2     rens     60   india
# 3      adi     82   india
# 4    harsh     92   india
# 5    ayush    104   india

# %% [markdown]
# renme the columns

# %%
df.rename(columns = {'Name': 'Student Name'}, inplace = True )
df
# Out:
#   Student Name  marks country
# 0         yash     70   india
# 1      harshit     55     usa
# 2         rens     60   india
# 3          adi     82   india
# 4        harsh     92   india
# 5        ayush    104   india

# %%
df.drop('country', inplace = True, axis = 1)
df
# Out:
#   Student Name  marks
# 0         yash     70
# 1      harshit     55
# 2         rens     60
# 3          adi     82
# 4        harsh     92
# 5        ayush    104

# %% [markdown]
# some  imp methods of pandas

# %%
df.isnull().sum()
# Out:
# Student Name    0
# marks           0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 3
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# np.int64(76)

# %%
df2.dropna(inplace = True)
df2
# Out:
#         age         job  marital            education  default housing loan  \
# 0      56.0   housemaid  married             basic.4y       no      no   no
# 1      57.0    services  married          high.school  unknown      no   no
# 2      37.0    services  married          high.school       no     yes   no
# 3      40.0      admin.  married             basic.6y       no      no   no
# 4      56.0    services  married          high.school       no      no  yes
# ...     ...         ...      ...                  ...      ...     ...  ...
# 41185  56.0     retired  married    university.degree       no     yes   no
# 41186  44.0  technician  married  professional.course       no      no   no
# 41187  74.0     retired  married  professional.course       no     yes   no
# 41193  94.0     retired  married  professional.course       no     yes   no
# 41194  74.0     retired  married  professional.course       no     yes   no
#
# ...

# %%
df2.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#grouping and aggregrate methods

df
# Out:
#   Student Name  marks
# 0         yash     70
# 1      harshit     55
# 2         rens     60
# 3          adi     82
# 4        harsh     92
# 5        ayush    104

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41190 entries, 0 to 41194
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41190 non-null  float64
#  1   job             41190 non-null  object
#  2   marital         41190 non-null  object
#  3   education       41190 non-null  object
#  4   default         41190 non-null  object
#  5   housing         41190 non-null  object
#  6   loan            41190 non-null  object
#  7   contact         41190 non-null  object
#  8   month           41190 non-null  object
#  9   day_of_week     41190 non-null  object
#  10  duration        41190 non-null  float64
#  11  campaign        41190 non-null  float64
#  12  pdays           41190 non-null  float64
#  13  previous        41190 non-null  float64
#  14  poutcome        41190 non-null  object
#  15  emp.var.rate    41190 non-null  float64
#  16  cons.price.idx  41190 non-null  float64
# ...

# %%
df2.groupby('marital')['age'].mean()
# Out:
# marital
# divorced    44.899393
# married     42.310509
# single      33.158714
# unknown     40.275000
# Name: age, dtype: float64

# %%
df
# Out:
#   Student Name  marks
# 0         yash     70
# 1      harshit     55
# 2         rens     60
# 3          adi     82
# 4        harsh     92
# 5        ayush    104

# %%
df
# Out:
#   Student Name  marks
# 0         yash     70
# 1      harshit     55
# 2         rens     60
# 3          adi     82
# 4        harsh     92
# 5        ayush    104

# %%
df['marks'].sum()
# Out:
# np.int64(463)

# %%
df['marks'].max()
# Out:
# 104

# %%
df.sort_values(by='marks', ascending= False)
# Out:
#   Student Name  marks
# 5        ayush    104
# 4        harsh     92
# 3          adi     82
# 0         yash     70
# 2         rens     60
# 1      harshit     55
